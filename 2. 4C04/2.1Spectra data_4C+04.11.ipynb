# %% [markdown]
# ### z = 4.5077

# %%
import numpy as np
import matplotlib.pyplot as plt
import astropy.units as u
from mpdaf.obj import Cube, WCS, WaveCoord  
#from astropy import units as u
from astropy.coordinates import SkyCoord
#%matplotlib notebook 
# %matplotlib inline

# %%
z = 4.5077 ### redshift

# %%
c = SkyCoord('03h11m47.97s', '+5d08m03.74s', frame='icrs')
print('degree ={}'.format(c))
# Out:
# degree =<SkyCoord (ICRS): (ra, dec) in deg
#     (47.949875, 5.13437222)>

# %% [markdown]
# RG = Cube('/Users/Ray/Desktop/Uni/7.Sem/ProjektAstro/Data/DATACUBE_4C04.11_ZAPmask_pipesky_fullFOV_mad_Astro_scaled_corr_zero.fits')
# RG.info()

# %% [markdown]
# cube_new = RG.copy()
# cube_new[:,175-50:175+50,157-50:157+50].write('4C+04.11_small.fits', savemask='dq')

# %%
RG2 = Cube('../All_Reduced_cubes/4C+04.11_small.fits')
RG2.info()
# Out:
# [INFO] 3681 x 100 x 100 Cube (../All_Reduced_cubes/4C+04.11_small.fits)
# [INFO] .data(3681 x 100 x 100) (1e-20 erg / (Angstrom cm2 s)), .var(3681 x 100 x 100)
# [INFO] center:(05:08:03.63721109,03:11:47.97790229) size:(20.000",20.000") step:(0.200",0.200") rot:-0.0 deg frame:FK5
# [INFO] wavelength: min:4749.81 max:9349.81 step:1.25 Angstrom

# %%
ra, dec = (47.949875, 5.13437222)
pix = RG2.wcs.sky2pix([dec,ra], unit=u.deg) 
x = int(np.around(pix[0][1]))
y1 = int(pix[0][0])
y = int(np.around(pix[0][0]))
print(y,x)
#make a copy of the (sub-)cube, prevent changing the original cube
cube_new_1 = RG2.copy()

#using pixel to get aperture r = 0.5 arcsec 
obj1 = cube_new_1.aperture((y,x), 2.5, unit_center=None,unit_radius=None) # is a spectum
obj1.info()
plt.figure(figsize=(8, 4))
#sp3 = obj2[:, y, x]
obj1.plot(title = 'Spectrum Center ra=%s dec=%s' %(ra, dec))
la_min = 4749.81
la_max = 9349.81
k = 3681
# Out:
# 50 50
# [INFO] 25 spaxels used
# [INFO] 3681 Spectrum (no name)
# [INFO] .data(3681) (1e-20 erg / (Angstrom cm2 s)), .var(3681)
# [INFO] wavelength: min:4749.81 max:9349.81 step:1.25 Angstrom

# %% [markdown]
# ### A list of emission lines

# %%
# restframe lines in vacuum 
my_lines_v = []
my_names = []
O_VI_d1_v = 1031.9 # doublet 
my_lines_v.append(O_VI_d1_v) 
my_names.append('O_VI_d1')
O_VI_d2_v = 1037.6 ### doublet
my_lines_v.append(O_VI_d2_v)
my_names.append('O_VI_d2')
C_II_f1_v = 1036.3 # fine structure line
my_lines_v.append(C_II_f1_v)
my_names.append('C_II_f1')
C_II_f2_v = 1037 ### fine
my_lines_v.append(C_II_f2_v)
my_names.append('C_II_f2')
He_II_p1_v = 1084.9
my_lines_v.append(He_II_p1_v)
my_names.append('He_II_p1')
Ly_alph_v = 1215.7
my_lines_v.append(Ly_alph_v)
my_names.append('Ly_alph')
N_V_d1_v = 1238.8 # doublet Ly_alpha
my_lines_v.append(N_V_d1_v)
my_names.append('N_V_d1')  
N_V_d2_v = 1242.8 # doublet NV broad
my_lines_v.append(N_V_d2_v)
my_names.append('N_V_d2')
Si_II_f1_v = 1264.7
my_lines_v.append(Si_II_f1_v)
my_names.append('Si_II_f1')
Si_II_f2_v = 1265 ### fine
my_lines_v.append(Si_II_f2_v)
my_names.append('Si_II_f2')
Si_II_f3_v = 1309.3
my_lines_v.append(Si_II_f3_v)
my_names.append('Si_II_f3')
C_II_f3_v = 1334.5
my_lines_v.append(C_II_f3_v)
my_names.append('C_II_f3')
C_II_f4_v = 1335.7 ### fine
my_lines_v.append(C_II_f4_v)
my_names.append('C_II_f4')
Si_IV_OIV_v = 1398
my_lines_v.append(Si_IV_OIV_v)
my_names.append('Si_IV_OIV')
Si_IV_d1_v = 1393.8
my_lines_v.append(Si_IV_d1_v)
my_names.append('Si_IV_d1')
Si_IV_d2_v = 1402.8 ### fine
my_lines_v.append(Si_IV_d2_v)
my_names.append('Si_IV_d2')  
N_IV_v = 1486.5
my_lines_v.append(N_IV_v)
my_names.append('N_IV')
Si_II_f4_v = 1526.7
my_lines_v.append(Si_II_f4_v)
my_names.append('Si_II_f4')
Si_II_f5_v = 1533.4
my_lines_v.append(Si_II_f5_v)
my_names.append('Si_II_f5')
C_IV_d1_v = 1542.9
my_lines_v.append(C_IV_d1_v)
my_names.append('C_IV_d1')
C_IV_d2_v = 1548.2
my_lines_v.append(C_IV_d2_v)
my_names.append('C_IV_d2')
Ne_V_v = 1575.1
my_lines_v.append(Ne_V_v)
my_names.append('Ne_V')
Ne_IV_p1_v = 1602.0
my_lines_v.append(Ne_IV_p1_v)
my_names.append('Ne_IV_p1')
He_II_p2_v = 1640.4
my_lines_v.append(He_II_p2_v)
my_names.append('He_II_p2')
O_III_d1_v = 1660.8
my_lines_v.append(O_III_d1_v)
my_names.append('O_III_d1')
O_III_d2_v = 1666.1
my_lines_v.append(O_III_d2_v)
my_names.append('O_III_d2')
N_III_v = 1749
my_lines_v.append(N_III_v)
my_names.append('N_III')
Si_II_f6_v = 1808
my_lines_v.append(Si_II_f6_v)
my_names.append('Si_II_f6')
Si_II_f7_v = 1816.9
my_lines_v.append(Si_II_f7_v)
my_names.append('Si_II_f7')
Si_II_f8_v = 1817.5 ### fine
my_lines_v.append(Si_II_f8_v)
my_names.append('Si_II_f8')  
Si_III_p1_v = 1882.5
my_lines_v.append(Si_III_p1_v)
my_names.append('Si_III_p1')
Si_III_p2_v = 1892
my_lines_v.append(Si_III_p2_v)
my_names.append('Si_III_p2')
C_III_d1_v = 1906.7
my_lines_v.append(C_III_d1_v)
my_names.append('C_III_d1')
C_III_d2_v = 1908.7 ### broad doublet
my_lines_v.append(C_III_d2_v)
my_names.append('C_III_d2')
C_II_v = 2326
my_lines_v.append(C_II_v)
my_names.append('C_II')
Ne_IV_p2_v = 2421.8
my_lines_v.append(Ne_IV_p2_v)
my_names.append('Ne_IV_p2')
O_II_v = 2471.0
my_lines_v.append(O_II_v)
my_names.append('O_II') #37

### extra lines from the q3d fit catalog
Mg_I_v = 2026.5
my_lines_v.append(Mg_I_v)
my_names.append('Mg_I') #38
Fe_VI_d1_v = 2145.8 
my_lines_v.append(Fe_VI_d1_v)
my_names.append('FeVI_d1') #39
Fe_VI_d2_v = 2163.7 
my_lines_v.append(Fe_VI_d2_v)
my_names.append('FeVI_d2') #40
Ca_VI_f1_v = 2214.5
my_lines_v.append(Ca_VI_f1_v)
my_names.append('Ca_VI_f1') 
Fe_II_f1_v = 2234.4
my_lines_v.append(Fe_II_f1_v)
my_names.append('Fe_II_f1') 
Ca_VI_f2_v = 2242.1
my_lines_v.append(Ca_VI_f2_v)
my_names.append('Ca_VI_f2') 
Fe_II_f2_v = 2249.9
my_lines_v.append(Fe_II_f2_v)
my_names.append('Fe_II_f2') 
Fe_II_f3_v = 2260.8
my_lines_v.append(Fe_II_f3_v)
my_names.append('Fe_II_f3')
### end of q3d fit catalog
C_II_v = 2326
my_lines_v.append(C_II_v)
my_names.append('C_II_v')
Ne_IV_p2_v = 2421.8
my_lines_v.append(Ne_IV_p2_v)
my_names.append('Ne_IV_p2')
O_II_v = 2471.0

my_lines =[]
num_of_lines = len(my_lines_v)
print(f'Number of lines: {num_of_lines}')


# convert into lambda in air and caculalte the expected lines 
def lamb_obs(z, lamb_v):
    s = 10**4/lamb_v
    n = 1+ 8.34254*1e-5+ 2.406147*1e-2/(130- s**2) + 1.5998*1e-4/(38.9- s**2)
    lamb_rest = lamb_v/n
    return lamb_rest*(z + 1)

##########
# new for line fitting
def lamb_rest_air(lamb_v):
    s = 10**4/lamb_v
    n = 1+ 8.34254*1e-5+ 2.406147*1e-2/(130- s**2) + 1.5998*1e-4/(38.9- s**2)
    lamb_rest = lamb_v/n
    return lamb_rest
index_rest_air = []
rest_air_lines = []

# my_rest_air = {} # is dictionary
for i, line in enumerate(my_lines_v):
    index_rest_air.append(i)
    rest_air_lines.append(np.around(lamb_rest_air(line), decimals=2))
#     my_rest_air[i] = [my_names[i], np.around(lamb_rest_air(line), decimals=2)]
# print(my_rest_air.values())
print(rest_air_lines,'\n', 'my_names')
doublet_list = ['O_VI_d1', 'C_II_f1', 'N_V_d1', 'Si_II_f1', 'C_II_f3', 'Si_IV_d1', 
                'Si_II_f4', 'C_IV_d1', 'O_III_d1','Si_III_p1', 'C_III_d1'] #Si_II_f1 is triplet
triplet_list = ['Si_II_f1', 'Si_II_f6']
def find_doublets(all_names, doub_list):
    """return the index of the first doublet lines"""
    index_of_doublets =[]
    for i, line in enumerate(all_names):
        for name in doub_list:
            if line == name:
                index_of_doublets.append(i)
    print(index_of_doublets)
    return index_of_doublets
find_doublets(my_names, doublet_list)
print(my_names[6])
##########

my_lines =[]
dict_lines = {}
for i, line in enumerate(my_lines_v):
    my_lines.append(np.around(lamb_obs(z, line), decimals=2))
    dict_lines[my_names[i]] = np.around(lamb_obs(z, line), decimals=2) 
    
for i, x in enumerate(dict_lines):
#     print(i+1,'\t',x, '\t', dict_lines[x])
    print(dict_lines[x])

#print(dict_lines)
print(my_lines)
doublet_list = []
for i, x in enumerate(my_lines[:-1]):
    if np.abs(x - my_lines[i+1]) <= 7*(1+z):
        doublet_list.append(x)
        doublet = x
        print(i, doublet)
# Out:
# Number of lines: 47
# [1031.13, 1036.84, 1035.54, 1036.24, 1084.23, 1215.14, 1238.24, 1242.25, 1264.15, 1264.45, 1308.76, 1333.97, 1335.17, 1397.48, 1393.27, 1402.28, 1485.99, 1526.21, 1532.92, 1542.43, 1547.74, 1574.73, 1605.39, 1639.69, 1660.13, 1665.44, 1748.38, 1807.38, 1816.28, 1816.88, 1881.87, 1891.37, 1906.07, 1908.07, 2325.29, 2421.06, 2470.25, 2025.85, 2145.12, 2163.02, 2213.81, 2233.71, 2241.4, 2249.2, 2260.1, 2325.29, 2421.06]
#  my_names
# [0, 2, 6, 8, 11, 14, 17, 19, 24, 30, 32]
# N_V_d1
# 5679.15
# 5710.63
# 5703.45
# 5707.31
# 5971.64
# 6692.61
# 6819.88
# 6841.92
# 6962.57
# 6964.22
# 7208.27
# 7347.09
# 7353.7
# 7696.87
# 7673.74
# 7723.31
# 8184.4
# 8405.92
# 8442.85
# 8495.24
# 8524.47
# 8673.11
# 8842.01
# 9030.91
# 9143.53
# 9172.75
# 9629.53
# 9954.49
# 10003.51
# 10006.81
# 10364.78
# 10417.09
# 10498.04
# 10509.06
# 12806.98
# 13334.5
# 13605.41
# 11157.76
# 11814.7
# 11913.27
# 12193.0
# 12302.58
# 12344.98
# 12387.93
# 12447.95
# 12806.98
# [5679.15, 5710.63, 5703.45, 5707.31, 5971.64, 6692.61, 6819.88, 6841.92, 6962.57, 6964.22, 7208.27, 7347.09, 7353.7, 7696.87, 7673.74, 7723.31, 8184.4, 8405.92, 8442.85, 8495.24, 8524.47, 8673.11, 8842.01, 9030.91, 9143.53, 9172.75, 9629.53, 9954.49, 10003.51, 10006.81, 10364.78, 10417.09, 10498.04, 10509.06, 12806.98, 13334.5, 13605.41, 11157.76, 11814.7, 11913.27, 12193.0, 12302.58, 12344.98, 12387.93, 12447.95, 12806.98, 13334.5]
# 0 5679.15
# 1 5710.63
# 2 5703.45
# 6 6819.88
# 8 6962.57
# 11 7347.09
# 13 7696.87
# 17 8405.92
# 19 8495.24
# 24 9143.53
# 28 10003.51
# 32 10498.04

# %% [markdown]
# ### 4 parts plot

# %% [markdown]
# ### Note that how many lines are in the range of the observation?

# %%
condition = (np.array(my_lines) >= la_max) | (np.array(my_lines) <= la_min)
in_range = num_of_lines - np.sum(np.extract(np.array(my_lines), condition))
condition_start = (np.array(my_lines) <= la_min)
start_line = np.sum(np.extract(np.array(my_lines), condition_start))
in_range += start_line
print(f'Number of lines in observation range: {in_range - start_line}')
print('First emission line: %s' %my_names[start_line])
print('Last emission line: %s' %my_names[in_range-1])
print('index of first and last emission lines : %d, %d' %(start_line, in_range-1))
# Out:
# Number of lines in observation range: 26
# First emission line: O_VI_d1
# Last emission line: O_III_d2
# index of first and last emission lines : 0, 25

# %%
# 3681 wavelengths
end = k
steps = end//4
print(f'steps ={steps}, last step ={end%4 + end//4}' )
wavelength = np.linspace(la_min, la_max, end)
### part 1 
plt.figure(figsize=(9, 4))
part1 = obj1[0:steps]
part1.plot(title = 'Spectrum 4C+04.11 part 1: %.2f to %.2f Å' %(wavelength[0], wavelength[steps]))
plt.ylim(-75, 145)
plt.xlim = (wavelength[0], wavelength[steps])

### mark the lines
ymin = -100
ymax = 400
label = 125 # position of the text
for x in dict_lines.keys():
    plt.vlines(dict_lines[x], ymin, ymax,label = x, ls = 'dashed' , colors= 'C1', lw =0.85)
    if dict_lines[x] <= wavelength[steps] and dict_lines[x] >= wavelength[0]: 
        plt.text(dict_lines[x] -30, label, x, rotation = 'vertical', va = 'center', c = 'C1')
plt.savefig('Spectra4C04_p1.png', format = 'png')
        
### part 2
plt.figure(figsize=(9, 4))
plt.ylim(-75, 150)
part2 = obj1[steps+1 :steps*2]
part2.plot(title = 'Spectrum 4C+04.11 part 2: %.2f to %.2f Å' %(wavelength[steps+1], wavelength[steps*2]))
for x in dict_lines.keys():
    plt.vlines(dict_lines[x], ymin, ymax,label = x, ls = 'dashed' , colors= 'C1', lw =0.85)
    if dict_lines[x] <= wavelength[steps*2] and dict_lines[x] >= wavelength[steps+1]: 
        plt.text(dict_lines[x] -30, label, x, rotation = 'vertical', va = 'center', c = 'C1')
plt.savefig('Spectra4C04_p2.png', format = 'png')        

### part3 
plt.figure(figsize=(9, 4))
plt.ylim(-75, 150) 
part3 = obj1[steps*2+1 :steps*3]
part3.plot(title = 'Spectrum 4C+04.11 part 3: %.2f to %.2f Å' %(wavelength[steps*2+1], wavelength[steps*3]))
for x in dict_lines.keys():
    plt.vlines(dict_lines[x], ymin, ymax,label = x, ls = 'dashed' , colors= 'C1', lw =0.85)
    if dict_lines[x] <= wavelength[steps*3] and dict_lines[x] >= wavelength[steps*2+1]: 
        plt.text(dict_lines[x] -30, label, x, rotation = 'vertical', va = 'center', c = 'C1')
plt.savefig('Spectra4C04_p3.png', format = 'png')   

plt.figure(figsize=(9, 4))
plt.ylim(-75, 150) 
part4 = obj1[steps*3+1 :end]
part4.plot(title = 'Spectrum 4C+04.11 part 4: %.2f to %.2f Å' %(wavelength[steps*3+1], wavelength[-1]))
for x in dict_lines.keys():
    plt.vlines(dict_lines[x], ymin, ymax,label = x, ls = 'dashed' , colors= 'C1', lw =0.85)
    if dict_lines[x] <= wavelength[end-1] and dict_lines[x] >= wavelength[steps*3+1]: 
        plt.text(dict_lines[x] -30, label, x, rotation = 'vertical', va = 'center', c = 'C1')
plt.savefig('Spectra4C04_p4.png', format = 'png')
# Out:
# steps =920, last step =921

# %% [markdown]
# ### Transform the spectra and zoom into each peak

# %%
from astropy import constants as const
z = 4.5077 ### redshift 
x_all = np.arange(obj1.get_range()[0],obj1.get_range()[1]+1, 1.25)
wavelength = np.linspace(la_min, la_max, k)

#transformation
def lamb2v(array, lambda_theo):
    """give the velocity of an array given in lambda in the frame of lambda_theo """
    vel = (array - lambda_theo)/lambda_theo* const.c*u.second/u.meter*1e-3
    return vel

# %% [markdown]
# ### 1. Continuum range selection
# #### func 1 algorithm for left and right continuum range:
# * Algorithm, condition if next peak in 1800 to 3800:
#            take next continuum

# %%
### a function that calculates the continuum range
### use p = peak, it = i, do_list = doublet_list, v_all = vel_all, mlines = my_lines
def get_continuum(p, it, do_list, mlines, v_all, beg_con_r =1800 , end_con_l = -1800):
    """return multiple variables in a tuple: (beg_con_r, end_con_r, beg_con_l, end_con_l, continuum_peak_left,
    continuum_peak_left)"""
    ### continuum range right 
    #beg_con_r = 1800  # CAN BE CHANGED
    end_con_r = beg_con_r +2000
    
    vel_prevline = np.array(lamb2v(mlines[it-1], p)) # in km/s
    vel_prevprevline = np.array(lamb2v(mlines[it-2], p)) # in km/s
    vel_nextline = np.array(lamb2v(mlines[it+1], p)) # in km/s
    vel_nextnextline = np.array(lamb2v(mlines[it+2], p)) # in km/s
    ### handle the close doublets which share the same continuum:
    if p in do_list:
        distance = lamb2v(mlines[it + 1], p)
        #FWHM = 1000
        beg_con_r += distance 
        #beg_con_r += (distance + FWHM) 
        end_con_r = 2000 + beg_con_r
        
    if (vel_nextline >= beg_con_r) & (vel_nextline <= end_con_r): ### take the cont. from next em. line
        FWHM = 3000  # CAN BE CHANGED
        distance = lamb2v(mlines[it+1], p) # could be initialized
        #beg_con += distance
        beg_con_r += (distance + FWHM/2)
        end_con_r = 2000 + beg_con_r
       #end_con = 1500 + distance + FWHM/2
        
    elif (vel_nextnextline >= beg_con_r) & (vel_nextnextline <= end_con_r):
        FWHM = 3000 # CAN BE CHANGED
        distance = lamb2v(mlines[i+2], p) # CAN BE CHANGED
        beg_con_r += (distance +FWHM/2)
        end_con_r = 2000 + beg_con_r
            
    condition1_r =  (vel_all >= beg_con_r) & (vel_all <= end_con_r)
    continuum_peak_right = np.extract(condition1_r, obj1.data)

    ### continuum range left
    end_con_l = -1800
    beg_con_l = end_con_l - 2000
    
        ### handle the close doublets which share the same continuum:
    if p in doublet_list:
        distance = lamb2v(mlines[it-1], p)
        #FWHM = 1000
        beg_con_l += distance 
        end_con_l = 2000 + beg_con_l
        
    if (vel_prevline >= beg_con_l) & (vel_prevline <= end_con_l): ### take the cont. from next em. line
        FWHM = 3000  # CAN BE CHANGED
        distance = lamb2v(mlines[it-1], p) # could be initialized
        beg_con_l += (distance + FWHM/2)
        end_con_l = 2000 + beg_con_l
        
    elif (vel_prevprevline >= beg_con_l) & (vel_prevprevline <= end_con_l):
        FWHM = 3000 # CAN BE CHANGED
        distance = lamb2v(mlines[it-2], p) # CAN BE CHANGED
        beg_con_l += (distance +FWHM/2)
        end_con_l = 2000 + beg_con_l
    
    condition1_l =  (vel_all >= beg_con_l) & (vel_all <= end_con_l)
    continuum_peak_left = np.extract(condition1_l, obj1.data)
    
    return beg_con_r, end_con_r, beg_con_l, end_con_l, continuum_peak_left, continuum_peak_right

# %% [markdown]
# #### func 2 maually determine the left and right continuum range for:
# * lambda 12 = Lyalph vac = from 1150
# * lambda 34 = N V vac = from 1254
# * lambda 3141 = SiII f1 vac = 1275
# * lambda 56 = Si II f4,f5, C IV d1,d2  vac = from 1485
# * lambda 78 = Si II f4,f5, C IV d1,d2 vac = from 1580

# %%
lamb1_v = 1150 #1180 #1160
lamb3_v = 1252 #1255
lamb31_v = 1275 #1266
lamb5_v = 1485 # 1475, 1480 left range of continuum SiII 
lamb7_v = 1580 #1577 
lamb1 = lamb_obs(z, lamb1_v)
lamb3 = lamb_obs(z, lamb3_v)
lamb31 = lamb_obs(z, lamb31_v)
lamb5 = lamb_obs(z, lamb5_v)
lamb7 = lamb_obs(z, lamb7_v)

### manually using a specific range for continuum for some lines
# it =i, p = peak, vp = vel_peak, o1 = obj1, diction = dict_lines, la1 = lambda1...
# comleft = continuum_peak_left, comright = continuum_peak_right, becon_r = r,  becon_l = l,
#end_con_r = encon_r, end_con_l = encon_l, myrange = in_range
def maual_continuum(it, p, vp, diction, la1, la3, la31, la5, la7, comright, comleft,
                    becon_r, becon_l, encon_l, encon_r, o1data, myrange):
    """return a tuple with 0. continuum vlaue, 1. continuum plot range left and 2. right 
    (con_val, x_l_func, x_r_func) """
    global in_range

    if p == diction['Ly_alph']: #Lyalph
        v1 = lamb2v(la1, p)
        v2 = v1 + 2000
        #v2 = lamb2v(lamb2, peak)
        condition_v1 =  (vp >= v1) & (vp <= v2)
        comleft = np.extract(condition_v1, o1data)
        v3 = lamb2v(la3, p)
        v4 = v3 + 2000
        condition_v3 =  (vp >= v3) & (vp <= v4)
        comright = np.extract(condition_v3, o1data)
        continuum_arr = np.append(comleft, comright)
        con_val = np.median(continuum_arr)
        x_l_func = np.linspace(v1, v2, 1000)
        x_r_func = np.linspace(v3, v4, 1000)
        comleft_range = np.extract(condition_v1, vp)
        print(len(continuum_arr), 'stdv',np.std(continuum_arr))
        sig_cont = np.std(continuum_arr)
        print(f'Ly_alph, cont = {con_val} \n left {np.median(comleft)} \n right{np.median(comright)}')
#         ax.axhline(np.median(comleft), color = 'cyan')
#         ax.axhline(np.median(comright), color = 'orchid')
#         ax.axhline(con_val, color = 'tan')
        
    elif p == diction['N_V_d1'] or p == diction['N_V_d2']: #N V d1:
        v1 = lamb2v(la1, p)
        v2 = v1 + 2000
        condition_v1 =  (vp >= v1) & (vp <= v2)
        comleft = np.extract(condition_v1, o1data)
        v3 = lamb2v(la3, peak)
        v4 = v3 + 2000
        condition_v3 =  (vp >= v3) & (vp <= v4)
        comright = np.extract(condition_v3, o1data)
        continuum_arr = np.append(comleft, comright)
        con_val = np.median(continuum_arr)
        sig_cont = np.std(continuum_arr)
        x_l_func = np.linspace(v1, v2, 1000)
        x_r_func = np.linspace(v3, v4, 1000) 
    
    elif p == diction['Si_II_f1']: 
        # Si II f1
        
        v3 = lamb2v(la3, p)
        v4 = v3 + 2000
        condition_v3 =  (vp >= v3) & (vp <= v4)
        comleft = np.extract(condition_v3, o1data)
        v31 = lamb2v(la31, p)
        v41 = v31 + 2000
        condition_v31 =  (vp >= v31) & (vp <= v41)
        comright = np.extract(condition_v31, o1data)
        continuum_arr = np.append(comleft, comright)
        sig_cont = np.std(continuum_arr)
        con_val = np.median(continuum_arr)
        x_l_func = np.linspace(v3, v4, 1000)
        x_r_func = np.linspace(v31, v41, 1000)
    
    elif p == diction['Si_II_f4'] or peak == diction['Si_II_f5']: # Si II f4,5:
        v5 = lamb2v(la5, p)
        v6 = v5 + 2000
        condition_v5 =  (vp >= v5) & (vp <= v6)
        comleft = np.extract(condition_v5, o1data)
        v7 = lamb2v(la7, peak)
        v8 = v7 + 2000
        condition_v7 =  (vp >= v7) & (vp <= v8)
        comright = np.extract(condition_v7, o1data)
        continuum_arr = np.append(comleft, comright)
        con_val = np.median(continuum_arr)
        sig_cont = np.std(continuum_arr)
        x_l_func = np.linspace(v5, v6, 1000)
        x_r_func = np.linspace(v7, v8, 1000)
        print(f'Si_II_f4, cont = {con_val} \n left {np.median(comleft)} \n right{np.median(comright)}')
        # for continuum check
#         ax.axhline(np.median(comleft), color = 'cyan')
#         ax.axhline(np.median(comright), color = 'orchid')
#         ax.axhline(con_val, color = 'tan')
        
    elif p == diction['C_IV_d1'] or p == diction['C_IV_d2']: # C IV d1, d2:
        v5 = lamb2v(lamb5, peak)
        v6 = v5 + 2000
        condition_v5 =  (vp >= v5) & (vp <= v6)
        comleft = np.extract(condition_v5, o1data)
        v7 = lamb2v(la7, p)
        v8 = v7 + 2000
        condition_v7 =  (vp >= v7) & (vp <= v8)
        comright = np.extract(condition_v7, o1data)
        continuum_arr = np.append(comleft, comright)
        con_val = np.median(continuum_arr)
        sig_cont = np.std(continuum_arr)
        x_l_func = np.linspace(v5, v6, 1000)
        x_r_func = np.linspace(v7, v8, 1000)
        print(f'C_IV_d1, cont = {con_val} \n left {np.median(comleft)} \n right{np.median(comright)}')
        # for continuum check
#         ax.axhline(np.median(comleft), color = 'cyan')
#         ax.axhline(np.median(comright), color = 'orchid')
#         ax.axhline(con_val, color = 'tan')

    elif p == diction['Ne_V']: # Ne_V
        v5 = lamb2v(lamb5, peak)
        v6 = v5 + 2000
        condition_v5 =  (vp >= v5) & (vp <= v6)
        comleft = np.extract(condition_v5, o1data)
        continuum_arr = np.append(comleft, comright)
        con_val = np.median(continuum_arr)
        sig_cont = np.std(continuum_arr)
        x_l_func = np.linspace(v5, v6, 1000)
        x_r_func = np.linspace(becon_r, encon_r, 1000)
    
    elif p == diction['He_II_p2'] or p == diction['O_III_d1']: # He II p2, O_III_d1
        v7 = lamb2v(la7, p)
        v8 = v7 + 2000
        condition_v7 =  (vp >= v7) & (vp <= v8)
        comleft = np.extract(condition_v7, o1data)
        continuum_arr = np.append(comleft, comright)
        con_val = np.median(continuum_arr)
        sig_cont = np.std(continuum_arr)
        x_l_func = np.linspace(v7, v8, 1000)
        x_r_func = np.linspace(becon_r, encon_r, 1000)
        
    elif it == 0:
        continuum_arr = continuum_peak_right ### original name because from the loop
        con_val = np.median(continuum_arr)
        sig_cont = np.std(continuum_arr)
        x_r_func = np.linspace(becon_r, encon_r, 1000)
        x_l_func = np.linspace(0,  0, 1000)
        #x_l = np.linspace(beg_con_l, end_con_l, 1000) 
        #print(con_val)
        
    elif it == myrange - 1:
        continuum_arr = continuum_peak_left
        con_val = np.median(continuum_arr)
        sig_cont = np.std(continuum_arr)
        x_l_func = np.linspace(becon_l, encon_l, 1000)
        x_r_func = np.linspace(0,  0, 1000)
        
    else:  ### all the other normal lines
        continuum_arr = np.append(continuum_peak_left, continuum_peak_right)
        con_val = np.median(continuum_arr)
        sig_cont = np.std(continuum_arr)
        x_l_func = np.linspace(becon_l, encon_l, 1000)
        x_r_func = np.linspace(becon_r, encon_r, 1000)
        print(f'cont = {con_val}')
    
    return con_val, x_l_func, x_r_func, sig_cont

# %% [markdown]
# ### S/N plot
# #### f3 color the signal and continuum range + threshold

# %%
### variable notes
# my_range = in_range
# vp = vel_peak
# y_data = b
# sigtonoise = S2N
# con_val = continuum_value 
# x_fl = x_l
# x_fr = x_r
# cond2 = condition2
# wavelen = wavelength
# p = peak
# Si_IIcut = SiIIf1 
def color_sncon(threshold, p, my_range, it, names, vp, con_val, cond2, wavelen, sigtonoise, y_data, x_fl, x_fr, Si_IIcut):
    """given the threshold plot all continuum and signal ranges"""
    if i < my_range: ### always plot the spectra and S/N value
        ax.step(vp, y_data - con_val, where='mid', label='mid',c= 'C0')#C0
        ax.text(0.02, 1.02, f'{it-(start_line-1)}. {names[it]}, S/N = {np.around(sigtonoise, decimals =2)}', size = 34, transform=ax.transAxes); ##### S2N
            
#         ax.set_title(f'Emission peak {names[it]}, S/N {np.around(sigtonoise, decimals=2)}', size = 18);
        ax.axhline(0, color = 'k')
        
        ### color the continuum region
        y1 = -100
        y2 = 1000
        ax.fill_between(x_l, y1, y2, color = 'C2', alpha = 0.5)
        ax.fill_between(x_r, y1, y2, color = 'C1', alpha = 0.5)
        
        #threshold of S/N#
        if S2N >= -threshold:
            width = []
            
            #######
            # fitting here
            #######
            
            ### color the signal and noise region (the same)
            start = lamb2v(np.extract(cond2, wavelen)[0], p)
            ### Si II f1 manual change
            if p ==  dict_lines['Si_II_f1']: 
                start = lamb2v(np.extract(cond2, wavelen)[Si_IIcut], p)
            stop = lamb2v(np.extract(cond2, wavelen)[-1], p)
            
            ax.axvline(start, color = 'red')
            ax.axvline(stop, color = 'red')
            ax.set_xlabel(r'velocity (km s$^{-1}$)', size = 20)
            ax.set_ylabel(r'Flux (1e-20 $erg\,\,\,Angstrom^{-1} cm^{-2} s^{-1})$', size = 18)

        else:
            ax.set_title('Below threshold')
    
    else:
        ax.grid(False)
        ax.set_xlabel('')
        ax.set_ylabel('')
        ax.set_title('No Data');

# %%
fig, axs = plt.subplots(9, 3, figsize=(74, 76)) #48
plt.subplots_adjust(left=None, bottom=None, right=None, top=None, wspace=None, hspace=0.3)

i = 0
# count the S/N
count_old = 0
count_new = 0
for ax, peak in zip(axs.flat, my_lines[:26]):
    ax.grid(False)
    #tick size
    ax.tick_params(axis='both', which='major', labelsize=20)
    ax.tick_params(axis='both', which='minor', labelsize=16)
    vel_all = np.array(lamb2v(x_all, peak)) # in km/s
    condition = np.abs(vel_all) <= 22500
    peak1 = np.extract(condition, obj1.data)
    new_peak1 = peak1.copy()
    #spectra data
    a = np.extract(condition, wavelength)
    b = new_peak1.data
    vel_peak = lamb2v(a, peak) # in km/s
    #print(len(vel_peak), len(vel_all), len(obj1.data))

    ### continuum range, f1
    beg_con_r, end_con_r, beg_con_l, end_con_l, continuum_peak_left, continuum_peak_right = get_continuum(peak, i, doublet_list, my_lines, vel_all, beg_con_r =1800 , end_con_l = -1800)
    
    print(i)
    
    #  generating continuum
    ## manually using a specific range for continuum for some line, use f2
    # since the variables are refered in the last fct, change the name of them
    spectradata = np.extract(condition, obj1.data)
    continuum_value, x_l, x_r, sig_cont = maual_continuum(i, peak, vel_peak, dict_lines, lamb1, lamb3, lamb31, lamb5, lamb7, continuum_peak_right, continuum_peak_right, beg_con_r, beg_con_l, end_con_l, end_con_r, spectradata, in_range)
    
    ### exception for Laser region
    if peak == 5793.36 or peak == 5794.73:
        ax.annotate(f'AO region, data not available', (0, 20),
                               ha='center', va='center', fontsize=25,
                               color='darkgrey')
        
        ax.grid(False)
    ymin = -50
    ymax = 100
    ax.set_ylim(ymin, ymax)
    
    ### S/N ratio
    d_lambda = 12*1.25 # resolution = 2 Wavelength channels --> 12 to avoid skylines
    arr = np.linspace(peak - d_lambda, peak + d_lambda, 6)
    FWHM = lamb2v(arr, peak)
    condition2 = np.abs(vel_all) <= np.max(FWHM)
    if i < in_range:
        
        signal_peak = np.extract(condition2, obj1.data - continuum_value) # use the continuum subtracted flux
        SiIIf1 = 2
        if peak ==  dict_lines['Si_II_f1']: ### skyline here
            signal_peak = signal_peak[SiIIf1:]
        new_sig_peak = signal_peak.copy()
        signal = np.sum(new_sig_peak)
        
        # get noise using only the STDV of the continuum range
        length = len(signal_peak)
        noise = (sig_cont**2*length)**0.5
        print('length = ',length)
        
        ### plot the noise spectra 
        peak2 = np.extract(condition, obj1.var)
        y_noise = np.sqrt(peak2.data)
        shift = 20
        ax.step(vel_peak, y_noise-shift, where='mid', label='mid',c= 'm', alpha = 0.8)
        ### 
         
        #signal_range = np.extract(condition2, vel_peak)
        S2N = signal/noise
        if S2N >= 3:
#             ax.text(0.95, 0.8, 'o', size = 66,alpha = 0.8, c = 'r', transform=ax.transAxes)
            # framing
            ax.patch.set_linewidth(7)
            ax.patch.set_edgecolor('cornflowerblue')
            # new background
            ax.set_facecolor('xkcd:off white') #dark grey
            count_new +=1
        if np.sum(new_sig_peak)/np.sum(obj1.var[condition2])**0.5 >= 3:
            count_old +=1
            
        ### comparison with the old method
#         print(my_names[i], '---------------')
#         for j in range(length):
#             print(j, new_sig_peak[j], obj1.var[condition2][j]**0.5)
            
#         print('noise:', np.std(new_sig_peak), 'noise_cont', sig_cont)
#         print('Signal to noise: ', np.sum(new_sig_peak)/np.sum(obj1.var[condition2])**0.5)
#         print('S/N: ', np.sum(new_sig_peak)/(sig_cont**2*length)**0.5)
        
    # Color the S,N and continuum range, f3 
    threshold = 10000
    color_sncon(threshold, peak, in_range, i, my_names, vel_peak, continuum_value, condition2, wavelength, S2N, b, x_l, x_r, SiIIf1)
    
    i+=1
    
print(f'S/N above 3 old: {count_old} --- new:{count_new}')
axs[8,2].remove()
plt.show()

# fig.suptitle('4C+04.11 26 emission lines continuum subtracted', size = 40);
fig.savefig("4C04.11_Spectra_S_N_ratio_noise_new.png", format="png")
#fig.savefig("4C04.11_Spectra_with_fit.pdf", format="pdf")
#fig.savefig('34_Spectra.png', format = 'png')
# Out:
# 0
# length =  24
# 1
# cont = 8.497925847768784
# length =  24
# 2
# cont = 6.845779813826084
# length =  24
# 3
# cont = 6.182534106075764
# length =  24
# 4
# cont = 6.773669429123402
# length =  24
# 5
# 71 stdv 10.079375848783505
# Ly_alph, cont = 16.040338814258575
#  left 9.504570860415697
#  right21.03391993045807
# length =  24
# 6
# length =  24
# 7
# length =  24
# /Users/Ray/opt/anaconda3/lib/python3.9/site-packages/numpy/core/fromnumeric.py:755: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   a.partition(kth, axis=axis, kind=kind, order=order)
# 8
# length =  22
# 9
# cont = 22.201992444694042
# length =  24
# 10
# cont = 20.52536427974701
# length =  24
# 11
# cont = 20.428403325378895
# length =  24
# 12
# cont = 20.949705999344587
# length =  24
# 13
# cont = 19.750569831579924
# length =  24
# 14
# cont = 22.198301295284182
# length =  24
# 15
# cont = 23.11249813437462
# length =  24
# 16
# cont = 23.350352615118027
# length =  24
# 17
# Si_II_f4, cont = 22.944679528474808
#  left 26.35863061621785
#  right20.3340602517128
# length =  24
# 18
# Si_II_f4, cont = 22.833383470773697
#  left 26.137116588652134
#  right20.3340602517128
# length =  24
# 19
# C_IV_d1, cont = 22.833383470773697
#  left 26.137116588652134
#  right20.3340602517128
# length =  24
# 20
# C_IV_d1, cont = 22.833383470773697
#  left 26.137116588652134
#  right20.3340602517128
# length =  24
# 21
# length =  24
# 22
# cont = 19.257449444849044
# length =  24
# 23
# length =  24
# 24
# length =  24
# 25
# length =  24
# S/N above 3 old: 14 --- new:12

# %% [markdown]
# ### Fit  single gaussians
# #### f4 replace f3 with one gaussian fit

# %% [markdown]
# from lmfit import Model
# from astropy import constants as const
# from numpy import exp, loadtxt, pi, sqrt

# %% [markdown]
# ### variable notes
# # my_range = in_range
# # vp = vel_peak
# # y_data = b
# # sigtonoise = S2N
# # con_val = continuum_value
# # x_fl = x_l
# # x_fr = x_r
# # cond2 = condition2
# # wavelen = wavelength
# # p = peak
# # Si_IIcut = SiIIf1
# def color_all_and_fit_doublet(mlines, threshold, p, my_range, it, names, vp, con_val, cond2, wavelen, sigtonoise, y_data, x_fl, x_fr, Si_IIcut):
#     """given the threshold plot all continuum and signal ranges, takes also my_line as parameter"""
#     if i < my_range: ### always plot the spectra and S/N value
#         ax.step(vp, y_data - con_val, where='mid', label='mid',c= 'C0')
#         ax.set_title(f'Emission peak {names[it]}, S/N {S2N}');
#         ax.axhline(0, color = 'k')
#
#         ### color the continuum region
#         y1 = -100
#         y2 = 1000
#         ax.fill_between(x_l, y1, y2, color = 'C2', alpha = 0.5)
#         ax.fill_between(x_r, y1, y2, color = 'C1', alpha = 0.5)
#
#         #threshold of S/N#
#         if S2N >= -threshold:
#
#             #######
#             ### do the fit
#             def gaussian(x, amp, cen, wid):
#                 """1-d gaussian: gaussian(x, amp, cen, wid)"""
#                 return (amp / (sqrt(2*pi) * wid)) * exp(-(x-cen)**2 / (2*wid**2))
#
#             gmodel = Model(gaussian, nan_policy = 'omit')
#             ### hint for parameters
# #             gmodel.set_param_hint('cen', value=0, min=-10, max=10)
#             FWHM_500 = 500/(2*(2*np.log(2))**0.5)
#             gmodel.set_param_hint('wid', value=100, min=0, max=FWHM_500)
#
#
#             # fit the left line
#             result_d1 = gmodel.fit(y_data, x=vp, amp= 1e4, cen=0, wid=100)#range add continuum
#             #result = gmodel.fit(b, x=vel_peak, amp= 1e5, cen = 0, wid=350 ) #range add continuum
#             amp_d1 = result_d1.best_values['amp']
#             cen_d1 = result_d1.best_values['cen']
#             wid_d1 = result_d1.best_values['wid']
#             print(result_d1.fit_report([['Fit Statistics']]))
#             ax.plot(vel_peak, result_d1.best_fit, '-', label='best fit', c= 'C2', ls = 'dashdot')
#
#             # fit the right line
#             #position of the next line
#             #vel_nextline = np.array(lamb2v(mlines[it+1], p)) # in km/s
#             la1 = lamb_rest_air(1542.9)
#             la2 = lamb_rest_air(1548.2)
#             c_light = const.c*u.second/u.meter*1e-3 # in km/s
#             vel_nextline = (cen_d1*la2+ la2*c_light- la1*c_light)/la1 # in km/s
#             print(f' VEL NEXT= {vel_nextline}')
# #             gmodel.set_param_hint('cen', value= vel_nextline, min=-10, max=10)
#             gmodel.set_param_hint('amp', value= amp_d1/2, min = amp_d1/2, max = amp_d1/2+100)
#             result_d2 = gmodel.fit(y_data, x = vp, amp= amp_d1/2, cen= vel_nextline, wid= wid_d1)#range add continuum
#             amp_d2 = result_d2.best_values['amp']
#             cen_d2 = result_d2.best_values['cen']
#             wid_d2 = result_d2.best_values['wid']
#             # skip the code below, continue w. the iteration
#             #continue
#             print(result_d2.fit_report([['Fit Statistics']]))
#             #plt.plot(x, result.init_fit, '--', label='initial fit')
#             ax.plot(vel_peak, result_d2.best_fit, '-', label='best fit', c= 'C4', ls = 'dashed')
#             ########## here the shell function
#             def double_gaussian(x, amp, cen1, cen2, wid, flux_factor = 2,):
#                 """1-d superposedd gaussian : gaussian(x, amp1, cen1, wid) + gaussian(x, amp1/2, cen2, wid)"""
#                 amp2 = amp/2
#                 return (amp / (sqrt(2*pi) * wid)) * exp(-(x-cen1)**2 / (2*wid**2)) + (amp2 / (sqrt(2*pi) * wid)) * exp(-(x-cen2)**2 / (2*wid**2))
#
#             doubleg_model = Model(double_gaussian, nan_policy = 'omit')
#             #fit
#             doubleg_model.set_param_hint('amp', value= amp_d1/2, min = amp_d1/2, max = amp_d1/2+100)
#             result_s = doubleg_model.fit(y_data, x = vp, amp= amp_d1/2, cen1= cen_d1, cen2= cen_d2, wid= wid_d1)#range add continuum
#             amp_d2 = result_d2.best_values['amp']
#             cen_d2 = result_d2.best_values['cen']
#             wid_d2 = result_d2.best_values['wid']
#
#             print(result_s.fit_report([['Fit Statistics']]))
#             ax.plot(vel_peak, result_s.best_fit, '-', label='best fit', c= 'b')
#             ##########
#
#
#
#             ax.annotate(
#             '$Amp = %.1f\cdot10^{-20}erg...$ \n $Cen = %.2f km/s$ \n $\Delta v = %.2f$ km/s \n $Amp_r =%.1f\cdot10^{-20}erg...$ \n $Cen_r = %.2f km/s$ \n $\Delta v_r = %.2f$ km/s'
#             %(amp_d1, cen_d1, wid_d1, amp_d2, cen_d2, wid_d2),
#             xy=(0, 0), xycoords='data',
#             xytext=(-300, 130), textcoords='offset points', #-195, 138
#             bbox=dict(boxstyle="round", fc="0.8"))
#
#             xmin = -4500 #4000
#             xmax = 4500 #4000
#             ymin = -20
#             ymax = 100
#             ax.set_ylim(ymin, ymax)
#             ax.set_xlim(xmin, xmax)
#             print(type(result_d1.fit_report()))
#             #######
#
#
#
#             ### color the signal and noise region (the same)
#             start = lamb2v(np.extract(cond2, wavelen)[0], p)
#             ### Si II f1 manual change
#             if p ==  dict_lines['Si_II_f1']:
#                 start = lamb2v(np.extract(cond2, wavelen)[Si_IIcut], p)
#             stop = lamb2v(np.extract(cond2, wavelen)[-1], p)
#
#             ax.axvline(start, color = 'red')
#             ax.axvline(stop, color = 'red')
#             ax.set_xlabel('velocity [km/s]', size = 8)
#             ax.set_ylabel(r'Flux 1e-20 $erg\,\,\,Angstrom^{-1} cm^{-2} s^{-1}$')
#
#         else:
#             ax.set_title('Below threshold')
#
#     else:
#         ax.grid(False)
#         ax.set_xlabel('')
#         ax.set_ylabel('')
#         ax.set_title('No Data');

# %%
#do the fit

# %% [markdown]
# ### Test C IV doublets

# %% [markdown]
# fig, axs = plt.subplots(1, 2, figsize=(32, 4)) #reihen, spalte,  ysize, xsize
#
# i = 19
# for ax, peak in zip(axs.flat, my_lines[19:20]):
#     ax.grid(True)
#     vel_all = np.array(lamb2v(x_all, peak)) # in km/s
#     condition = np.abs(vel_all) <= 21700
#     peak1 = np.extract(condition, obj1.data)
#     new_peak1 = peak1.copy()
#     #spectra data
#     a = np.extract(condition, wavelength)
#     b = new_peak1.data
#     vel_peak = lamb2v(a, peak) # in km/s
#     #print(len(vel_peak), len(vel_all), len(obj1.data))
#
#     ### continuum range, f1
#     beg_con_r, end_con_r, beg_con_l, end_con_l, continuum_peak_left, continuum_peak_right = get_continuum(peak, i, doublet_list, my_lines, vel_all, beg_con_r =1800 , end_con_l = -1800)
#
#     print(i)
#
#     #  generating continuum
#     ## manually using a specific range for continuum for some line, use f2
#     # since the variables are refered in the last fct, change the name of them
#     spectradata = np.extract(condition, obj1.data)
#     continuum_value, x_l, x_r, sig_cont = maual_continuum(i, peak, vel_peak, dict_lines, lamb1, lamb3, lamb31, lamb5, lamb7, continuum_peak_right, continuum_peak_right, beg_con_r, beg_con_l, end_con_l, end_con_r, spectradata, in_range)
#
#     ### exception for Laser region
#     if peak == 5793.36 or peak == 5794.73:
#         ax.annotate(f'AO region, data not available', (0, 20),
#                                ha='center', va='center', fontsize=25,
#                                color='darkgrey')
#
#         ax.grid(False)
#     ymin = -50
#     ymax = 100
#     ax.set_ylim(ymin, ymax)
#
#     ### S/N ratio
#     d_lambda = 12*1.25 # resolution = 2 Wavelength channels --> 12 to avoid skylines
#     arr = np.linspace(peak - d_lambda, peak + d_lambda, 6)
#     FWHM = lamb2v(arr, peak)
#     condition2 = np.abs(vel_all) <= np.max(FWHM)
#     if i < in_range:
#
#         signal_peak = np.extract(condition2, obj1.data - continuum_value) # use the continuum subtracted flux
#         SiIIf1 = 2
#         if peak ==  dict_lines['Si_II_f1']: ### skyline here
#             signal_peak = signal_peak[SiIIf1:]
#         new_sig_peak = signal_peak.copy()
#         signal = np.sum(new_sig_peak)
#
#
#         # get noise option2 use data extension of cube
#         # without sigma continuum
#         #noise = np.sum(np.extract(condition2, obj1.var))**0.5
#         noise_cont = np.sum(np.extract(condition2, obj1.var))**0.5
#         noise = np.sqrt(noise_cont**2 + sig_cont**2)
#
#         #signal_range = np.extract(condition2, vel_peak)
#         S2N = signal/noise
#         ### test the range of signal and noise subtraction
#         length = len(obj1.data)
#         index = np.linspace(0,length - 1,length)
#         #print(np.extract(condition2, index))
#
#     # Color the S,N and continuum range, f3
#     threshold = 10000
#     color_all_and_fit_doublet(my_lines, threshold, peak, in_range, i, my_names, vel_peak, continuum_value, condition2, wavelength, S2N, b, x_l, x_r, SiIIf1)
#
#     i+=1
#
# plt.show()
# # fig.suptitle('4C+04.11 26 emission lines continuum subtracted', size = 40);
# #fig.savefig("4C04.11_Spectra_S_N_ratio_noise_new.pdf", format="pdf")
# #fig.savefig("4C04.11_Spectra_with_fit.pdf", format="pdf")
# #fig.savefig('34_Spectra.png', format = 'png')

# %% [markdown]
# ### Test N V lines

# %% [markdown]
# ### variable notes
# # my_range = in_range
# # vp = vel_peak
# # y_data = b
# # sigtonoise = S2N
# # con_val = continuum_value
# # x_fl = x_l
# # x_fr = x_r
# # cond2 = condition2
# # wavelen = wavelength
# # p = peak
# # Si_IIcut = SiIIf1
# def color_all_and_fit_doublet(mlines, threshold, p, my_range, it, names, vp, con_val, cond2, wavelen, sigtonoise, y_data, x_fl, x_fr, Si_IIcut):
#     """given the threshold plot all continuum and signal ranges, takes also my_line as parameter"""
#     if i < my_range: ### always plot the spectra and S/N value
#         ax.step(vp, y_data - con_val, where='mid', label='mid',c= 'C0')
#         ax.set_title(f'Emission peak {names[it]}, S/N {S2N}');
#         ax.axhline(0, color = 'k')
#
#         ### color the continuum region
#         y1 = -100
#         y2 = 1000
#         ax.fill_between(x_l, y1, y2, color = 'C2', alpha = 0.5)
#         ax.fill_between(x_r, y1, y2, color = 'C1', alpha = 0.5)
#
#         #threshold of S/N#
#         if S2N >= -threshold:
#
#             #######
#             ### do the fit
#             def gaussian(x, amp, cen, wid):
#                 """1-d gaussian: gaussian(x, amp, cen, wid)"""
#                 return (amp / (sqrt(2*pi) * wid)) * exp(-(x-cen)**2 / (2*wid**2))
#
#             gmodel = Model(gaussian, nan_policy = 'omit')
#             ### hint for parameters
# #             gmodel.set_param_hint('cen', value=0, min=-10, max=10)
#             FWHM_500 = 500/(2*(2*np.log(2))**0.5)
#             gmodel.set_param_hint('wid', value=100, min=0, max=FWHM_500)
#
#             # fit the left line
#             result_d1 = gmodel.fit(y_data, x=vp, amp= 1e4, cen=0, wid=100)#range add continuum
#             #result = gmodel.fit(b, x=vel_peak, amp= 1e5, cen = 0, wid=350 ) #range add continuum
#             amp_d1 = result_d1.best_values['amp']
#             cen_d1 = result_d1.best_values['cen']
#             wid_d1 = result_d1.best_values['wid']
#             print(result_d1.fit_report([['Fit Statistics']]))
#             ax.plot(vel_peak, result_d1.best_fit, '-', label='best fit', c= 'C2', ls = 'dashdot')
#
#             # fit the right line
#             #position of the next line
#             #vel_nextline = np.array(lamb2v(mlines[it+1], p)) # in km/s
#             la1 = rest_air_lines[6]
#             la2 = rest_air_lines[7]
# #             la2 = lamb_rest_air(1548.2)
#             c_light = const.c*u.second/u.meter*1e-3 # in km/s
#             vel_nextline = (cen_d1*la2+ la2*c_light- la1*c_light)/la1 # in km/s
#             print(f' VEL NEXT= {vel_nextline}')
#             gmodel.set_param_hint('cen', value= vel_nextline) #, min= vel_nextline-10, max= vel_nextline+10) ###
#             gmodel.set_param_hint('amp', value= amp_d1/2, min = amp_d1/2, max = amp_d1/2+100)
#             result_d2 = gmodel.fit(y_data, x = vp, amp= amp_d1/2, cen= vel_nextline, wid= wid_d1)#range add continuum
#             amp_d2 = result_d2.best_values['amp']
#             cen_d2 = result_d2.best_values['cen']
#             wid_d2 = result_d2.best_values['wid']
#             # skip the code below, continue w. the iteration
#             #continue
#             print(result_d2.fit_report([['Fit Statistics']]))
#             #plt.plot(x, result.init_fit, '--', label='initial fit')
#             ax.plot(vel_peak, result_d2.best_fit, '-', label='best fit', c= 'C4', ls = 'dashed')
#             ########## here the shell function
#             def double_gaussian(x, amp, cen1, cen2, wid, flux_factor = 2,):
#                 """1-d superposedd gaussian : gaussian(x, amp1, cen1, wid) + gaussian(x, amp1/2, cen2, wid)"""
#                 amp2 = amp/2
#                 return (amp / (sqrt(2*pi) * wid)) * exp(-(x-cen1)**2 / (2*wid**2)) + (amp2 / (sqrt(2*pi) * wid)) * exp(-(x-cen2)**2 / (2*wid**2))
#
#             doubleg_model = Model(double_gaussian, nan_policy = 'omit')
#             #fit
#             doubleg_model.set_param_hint('amp', value= amp_d1/2, min = amp_d1/2, max = amp_d1/2+100)
#             result_s = doubleg_model.fit(y_data, x = vp, amp= amp_d1/2, cen1= cen_d1, cen2= cen_d2, wid= wid_d1)#range add continuum
#             amp_d2 = result_d2.best_values['amp']
#             cen_d2 = result_d2.best_values['cen']
#             wid_d2 = result_d2.best_values['wid']
#
#             print(result_s.fit_report([['Fit Statistics']]))
#             ax.plot(vel_peak, result_s.best_fit, '-', label='best fit', c= 'b')
#             ##########
#
#
#
#             ax.annotate(
#             '$Amp = %.1f\cdot10^{-20}erg...$ \n $Cen = %.2f km/s$ \n $\Delta v = %.2f$ km/s \n $Amp_r =%.1f\cdot10^{-20}erg...$ \n $Cen_r = %.2f km/s$ \n $\Delta v_r = %.2f$ km/s'
#             %(amp_d1, cen_d1, wid_d1, amp_d2, cen_d2, wid_d2),
#             xy=(0, 0), xycoords='data',
#             xytext=(-300, 130), textcoords='offset points', #-195, 138
#             bbox=dict(boxstyle="round", fc="0.8"))
#
#             xmin = -3000 #4000
#             xmax = 3000 #4000
#             ymin = -20
#             ymax = 100
#             ax.set_ylim(ymin, ymax)
#             ax.set_xlim(xmin, xmax)
#             print(type(result_d1.fit_report()))
#             #######
#
#
#
#             ### color the signal and noise region (the same)
#             start = lamb2v(np.extract(cond2, wavelen)[0], p)
#             ### Si II f1 manual change
#             if p ==  dict_lines['Si_II_f1']:
#                 start = lamb2v(np.extract(cond2, wavelen)[Si_IIcut], p)
#             stop = lamb2v(np.extract(cond2, wavelen)[-1], p)
#
#             ax.axvline(start, color = 'red')
#             ax.axvline(stop, color = 'red')
#             ax.set_xlabel('velocity [km/s]', size = 8)
#             ax.set_ylabel(r'Flux 1e-20 $erg\,\,\,Angstrom^{-1} cm^{-2} s^{-1}$')
#
#         else:
#             ax.set_title('Below threshold')
#
#     else:
#         ax.grid(False)
#         ax.set_xlabel('')
#         ax.set_ylabel('')
#         ax.set_title('No Data');

# %% [markdown]
# fig, axs = plt.subplots(1, 2, figsize=(32, 4)) #reihen, spalte,  ysize, xsize
#
# i = 6
# for ax, peak in zip(axs.flat, my_lines[6:8]):
#     ax.grid(True)
#     vel_all = np.array(lamb2v(x_all, peak)) # in km/s
#     condition = np.abs(vel_all) <= 21700
#     peak1 = np.extract(condition, obj1.data)
#     new_peak1 = peak1.copy()
#     #spectra data
#     a = np.extract(condition, wavelength)
#     b = new_peak1.data
#     vel_peak = lamb2v(a, peak) # in km/s
#     #print(len(vel_peak), len(vel_all), len(obj1.data))
#
#     ### continuum range, f1
#     beg_con_r, end_con_r, beg_con_l, end_con_l, continuum_peak_left, continuum_peak_right = get_continuum(peak, i, doublet_list, my_lines, vel_all, beg_con_r =1800 , end_con_l = -1800)
#
#     print(i)
#
#     #  generating continuum
#     ## manually using a specific range for continuum for some line, use f2
#     # since the variables are refered in the last fct, change the name of them
#     spectradata = np.extract(condition, obj1.data)
#     continuum_value, x_l, x_r, sig_cont = maual_continuum(i, peak, vel_peak, dict_lines, lamb1, lamb3, lamb31, lamb5, lamb7, continuum_peak_right, continuum_peak_right, beg_con_r, beg_con_l, end_con_l, end_con_r, spectradata, in_range)
#
#     ### exception for Laser region
#     if peak == 5793.36 or peak == 5794.73:
#         ax.annotate(f'AO region, data not available', (0, 20),
#                                ha='center', va='center', fontsize=25,
#                                color='darkgrey')
#
#         ax.grid(False)
#     ymin = -50
#     ymax = 100
#     ax.set_ylim(ymin, ymax)
#
#     ### S/N ratio
#     d_lambda = 12*1.25 # resolution = 2 Wavelength channels --> 12 to avoid skylines
#     arr = np.linspace(peak - d_lambda, peak + d_lambda, 6)
#     FWHM = lamb2v(arr, peak)
#     condition2 = np.abs(vel_all) <= np.max(FWHM)
#     if i < in_range:
#
#         signal_peak = np.extract(condition2, obj1.data - continuum_value) # use the continuum subtracted flux
#         SiIIf1 = 2
#         if peak ==  dict_lines['Si_II_f1']: ### skyline here
#             signal_peak = signal_peak[SiIIf1:]
#         new_sig_peak = signal_peak.copy()
#         signal = np.sum(new_sig_peak)
#
#
#         # get noise option2 use data extension of cube
#         # without sigma continuum
#         #noise = np.sum(np.extract(condition2, obj1.var))**0.5
#         noise_cont = np.sum(np.extract(condition2, obj1.var))**0.5
#         noise = np.sqrt(noise_cont**2 + sig_cont**2)
#
#         #signal_range = np.extract(condition2, vel_peak)
#         S2N = signal/noise
#         ### test the range of signal and noise subtraction
#         length = len(obj1.data)
#         index = np.linspace(0,length - 1,length)
#         #print(np.extract(condition2, index))
#
#     # Color the S,N and continuum range, f3
#     threshold = 10000
#     color_all_and_fit_doublet(my_lines, threshold, peak, in_range, i, my_names, vel_peak, continuum_value, condition2, wavelength, S2N, b, x_l, x_r, SiIIf1)
#
#     i+=1
#
# plt.show()
# # fig.suptitle('4C+04.11 26 emission lines continuum subtracted', size = 40);
# #fig.savefig("4C04.11_Spectra_S_N_ratio_noise_new.pdf", format="pdf")
# #fig.savefig("4C04.11_Spectra_with_fit.pdf", format="pdf")
# #fig.savefig('34_Spectra.png', format = 'png')

# %% [markdown]
# ### variable notes
# # my_range = in_range
# # vp = vel_peak
# # y_data = b
# # sigtonoise = S2N
# # con_val = continuum_value
# # x_fl = x_l
# # x_fr = x_r
# # cond2 = condition2
# # wavelen = wavelength
# # p = peak
# # Si_IIcut = SiIIf1
# def color_and_fit(threshold, p, my_range, it, names, vp, con_val, cond2, wavelen, sigtonoise, y_data, x_fl, x_fr, Si_IIcut):
#     """given the threshold plot all continuum and signal ranges"""
#     if i < my_range: ### always plot the spectra and S/N value
#         ax.step(vp, y_data - con_val, where='mid', label='mid',c= 'C0')
#         ax.set_title(f'Emission peak {names[it]}, S/N {S2N}');
#         ax.axhline(0, color = 'k')
#
#         ### color the continuum region
#         y1 = -100
#         y2 = 1000
#         ax.fill_between(x_l, y1, y2, color = 'C2', alpha = 0.5)
#         ax.fill_between(x_r, y1, y2, color = 'C1', alpha = 0.5)
#
#         #threshold of S/N#
#         if S2N >= -threshold:
#             width = []
#             #######
#             ### do the fit
#             def gaussian_with_base(x, amp, cen, wid ):
#                 """1-d gaussian: gaussian(x, amp, cen, wid)"""
#                 return (amp / (sqrt(2*pi) * wid)) * exp(-(x-cen)**2 / (2*wid**2))
#
#             gmodel = Model(gaussian_with_base, nan_policy = 'omit')
#             ### hint for parameters
#             gmodel.set_param_hint('cen', value=0, min=-10, max=10)
#             gmodel.set_param_hint('wid', value=100, min=0, max=(500/(2*(2*np.log(2))**2))
#             # skip the code below, continue w. the iteration
#             #continue
#
#             result = gmodel.fit(b, x=vel_peak, amp= 1e5, cen = 0, wid=350 ) #range add continuum
#             amp = result.best_values['amp']
#             cen = result.best_values['cen']
#             wid = result.best_values['wid']
#             width.append(wid)
#             print(result.fit_report([['Fit Statistics']]))
#             #plt.plot(x, result.init_fit, '--', label='initial fit')
#             ax.plot(vel_peak, result.best_fit, '-', label='best fit', c= 'C2')
#             ax.annotate(
#             'Amp = %.1f $10^{-20}erg...$ \n $Cen = %.2f km/s$ \n $\Delta v = %.2f$ km/s' %(amp, cen, wid),
#             xy=(0, 0), xycoords='data',
#             xytext=(-195, 135), textcoords='offset points',
#             bbox=dict(boxstyle="round", fc="0.8"))
#
#             xmin = -4000
#             xmax = 4000
#             ymin = -20
#             ymax = 100
#             #fig, ax = plt.subplots()
#             ax.set_ylim(ymin, ymax)
#             ax.set_xlim(xmin, xmax)
#             #print(type(result.fit_report()))
#
# #             if p == dict_lines['C_IV_d2']:
# #                 result = gmodel.fit(b, x = vp, amp= 1e5, cen = 0, wid= width[it-1]) #range add continuum
#
#             #######
#
#             ### color the signal and noise region (the same)
#             start = lamb2v(np.extract(cond2, wavelen)[0], p)
#             ### Si II f1 manual change
#             if p ==  dict_lines['Si_II_f1']:
#                 start = lamb2v(np.extract(cond2, wavelen)[Si_IIcut], p)
#             stop = lamb2v(np.extract(cond2, wavelen)[-1], p)
#
#             ax.axvline(start, color = 'red')
#             ax.axvline(stop, color = 'red')
#             ax.set_xlabel('velocity [km/s]', size = 8)
#             ax.set_ylabel(r'Flux 1e-20 $erg\,\,\,Angstrom^{-1} cm^{-2} s^{-1}$')
#
#         else:
#             ax.set_title('Below threshold')
#
#     else:
#         ax.grid(False)
#         ax.set_xlabel('')
#         ax.set_ylabel('')
#         ax.set_title('No Data');

# %% [markdown]
# fig, axs = plt.subplots(9, 3, figsize=(54, 42))
#
# i = 0
# for ax, peak in zip(axs.flat, my_lines[:26]):
#     ax.grid(True)
#     vel_all = np.array(lamb2v(x_all, peak)) # in km/s
#     condition = np.abs(vel_all) <= 21000
#     peak1 = np.extract(condition, obj1.data)
#     new_peak1 = peak1.copy()
#     #spectra data
#     a = np.extract(condition, wavelength)
#     b = new_peak1.data
#     vel_peak = lamb2v(a, peak) # in km/s
#     #print(len(vel_peak), len(vel_all), len(obj1.data))
#
#     ### continuum range, f1
#     beg_con_r, end_con_r, beg_con_l, end_con_l, continuum_peak_left, continuum_peak_right = get_continuum(peak, i, doublet_list, my_lines, vel_all, beg_con_r =1800 , end_con_l = -1800)
#
#     print(i)
#
#     #  generating continuum
#     ## manually using a specific range for continuum for some line, use f2
#     # since the variables are refered in the last fct, change the name of them
#     spectradata = np.extract(condition, obj1.data)
#     continuum_value, x_l, x_r, sig_cont = maual_continuum(i, peak, vel_peak, dict_lines, lamb1, lamb3, lamb31, lamb5, lamb7, continuum_peak_right, continuum_peak_right, beg_con_r, beg_con_l, end_con_l, end_con_r, spectradata, in_range)
#
#     ### exception for Laser region
#     if peak == 5793.36 or peak == 5794.73:
#         ax.annotate(f'AO region, data not available', (0, 20),
#                                ha='center', va='center', fontsize=25,
#                                color='darkgrey')
#
#         ax.grid(False)
#     ymin = -50
#     ymax = 100
#     ax.set_ylim(ymin, ymax)
#
#     ### S/N ratio
#     d_lambda = 12*1.25 # resolution = 2 Wavelength channels --> 12 to avoid skylines
#     arr = np.linspace(peak - d_lambda, peak + d_lambda, 6)
#     FWHM = lamb2v(arr, peak)
#     condition2 = np.abs(vel_all) <= np.max(FWHM)
#     if i < in_range:
#
#         signal_peak = np.extract(condition2, obj1.data - continuum_value) # use the continuum subtracted flux
#         SiIIf1 = 2
#         if peak ==  dict_lines['Si_II_f1']: ### skyline here
#             signal_peak = signal_peak[SiIIf1:]
#         new_sig_peak = signal_peak.copy()
#         signal = np.sum(new_sig_peak)
#
#
#         # get noise option2 use data extension of cube
#         # without sigma continuum
#         #noise = np.sum(np.extract(condition2, obj1.var))**0.5
#         noise_cont = np.sum(np.extract(condition2, obj1.var))**0.5
#         noise = np.sqrt(noise_cont**2 + sig_cont**2)
#
#         #signal_range = np.extract(condition2, vel_peak)
#         S2N = signal/noise
#         ### test the range of signal and noise subtraction
#         length = len(obj1.data)
#         index = np.linspace(0,length - 1,length)
#         #print(np.extract(condition2, index))
#
#     # Color the S,N and continuum range, f3
#     threshold = -3 # negative threshold number
#     color_and_fit(threshold, peak, in_range, i, my_names, vel_peak, continuum_value, condition2, wavelength, S2N, b, x_l, x_r, SiIIf1)
#
#     i+=1
#
# plt.show()
# fig.suptitle('4C+04.11 line fit', size = 40);
# fig.savefig("4C04.11_Spectra_S_N_greater_3_fit.pdf", format="pdf")
# #fig.savefig("4C04.11_Spectra_with_fit.pdf", format="pdf")
# #fig.savefig('34_Spectra.png', format = 'png')

# %% [markdown]
# ### double gaussian

# %% [markdown]
# fig, axs = plt.subplots(9, 3, figsize=(54, 42))
#
# i = 19
# for ax, peak in zip(axs.flat, my_lines[19:21]):
#     ax.grid(True)
#     vel_all = np.array(lamb2v(x_all, peak)) # in km/s
#     condition = np.abs(vel_all) <= 21000
#     peak1 = np.extract(condition, obj1.data)
#     new_peak1 = peak1.copy()
#     #spectra data
#     a = np.extract(condition, wavelength)
#     b = new_peak1.data
#     vel_peak = lamb2v(a, peak) # in km/s
#
#     ### continuum range, f1
#     beg_con_r, end_con_r, beg_con_l, end_con_l, continuum_peak_left, continuum_peak_right = get_continuum(peak, i, doublet_list, my_lines, vel_all, beg_con_r =1800 , end_con_l = -1800)
#
#     print(i)
#
#     #  generating continuum
#     ## manually using a specific range for continuum for some line, use f2
#     # since the variables are refered in the last fct, change the name of them
#     continuum_value, x_l, x_r = maual_continuum(i, peak, vel_peak, dict_lines, lamb1, lamb3, lamb31, lamb5, lamb7, continuum_peak_right, continuum_peak_right, beg_con_r, beg_con_l, end_con_l, end_con_r, obj1, in_range)
#
#     ### exception for Laser region
#     if peak == 5793.36 or peak == 5794.73:
#         ax.annotate(f'AO region, data not available', (0, 20),
#                                ha='center', va='center', fontsize=25,
#                                color='darkgrey')
#
#         ax.grid(False)
#     ymin = -50
#     ymax = 100
#     ax.set_ylim(ymin, ymax)
#
#     ### S/N ratio
#     d_lambda = 12*1.25 # resolution = 2 Wavelength channels --> 12 to avoid skylines
#     arr = np.linspace(peak - d_lambda, peak + d_lambda, 6)
#     FWHM = lamb2v(arr, peak)
#     condition2 = np.abs(vel_all) <= np.max(FWHM)
#     if i < in_range:
#
#         signal_peak = np.extract(condition2, obj1.data - continuum_value) # use the continuum subtracted flux
#         SiIIf1 = 2
#         if peak ==  dict_lines['Si_II_f1']: ### skyline here
#             signal_peak = signal_peak[SiIIf1:]
#         new_sig_peak = signal_peak.copy()
#         signal = np.sum(new_sig_peak)
#
#
#         # get noise option2 use data extension of cube
#         noise = np.sum(np.extract(condition2, obj1.var))**0.5
#
#         #signal_range = np.extract(condition2, vel_peak)
#         S2N = signal/noise
#         ### test the range of signal and noise subtraction
#         length = len(obj1.data)
#         index = np.linspace(0,length - 1,length)
#         #print(np.extract(condition2, index))
#
#     # Color the S,N and continuum range, f3
#     threshold = 10000
#     color_sncon(threshold, peak, in_range, i, my_names, vel_peak, continuum_value, condition2, wavelength, S2N, b, x_l, x_r, SiIIf1)
#     ##### Fit here:
#     if i < in_range:
#         if S2N >= -threshold:
#             #######
#             ### do the fit
#             def double_gaussian(x, amp1, amp2, cen1, cen2, wid):
#                 """1-d gaussian: gaussian(x, amp, cen, wid)"""
#                 return (amp1 / (sqrt(2*pi) * wid)) * exp(-(x-cen1)**2 / (2*wid**2)) + (amp2 / (sqrt(2*pi) * wid)) * exp(-(x-cen2)**2 / (2*wid**2))
#
#             gmodel = Model(gaussian_with_base, nan_policy = 'omit')
#             ### hint for parameters
#             gmodel.set_param_hint('cen', value=0, min=-10, max=10)
#             gmodel.set_param_hint('wid', value=100, min=0, max=500)
#
#
#             ymin = -50
#             ymax = 100
#             ax.set_ylim(ymin, ymax)
#             # skip the code below, continue w. the iteration
#             #continue
#
#             #get next emission line position:
#             vel_nextline = np.array(lamb2v(my_lines[i+1], peak)) # in km/s ### here must take a look
#             print(vel_nextline)
#
# #             result = gmodel.fit(b, x=vel_peak, amp1= 1e5, cen1 = 0, cen2 = vel_nextline, wid=350 ) #range add continuum
# #             ampleft = result.best_values['amp1']
# #             ampright = result.best_values['amp2']
# #             cenleft= result.best_values['cen1']
# #             cenright= result.best_values['cen2']
# #             wid = result.best_values['wid']
# #             width.append(wid)
# #             #print(result.fit_report([['Fit Statistics']]))
# #             #ax.plot(x, result.init_fit, '--', label='initial fit')
# #             ax.plot(vel_peak, result.best_fit, '-', label='best fit', c= 'C2')
# #             ax.annotate(
# #             'Amp, left = %.1f $10^{-20}erg...$ \n Amp, right = %.1f $10^{-20}erg...$ \n $Cen,left = %.2f km/s$, $Cen, right = %.2f km/s$ \n $\Delta v = %.2f$ km/s' %(amp1, amp2, cen1, cen2, wid),
# #             xy=(0, 0), xycoords='data',
# #             xytext=(-250, 140), textcoords='offset points',
# #             bbox=dict(boxstyle="round", fc="0.8"))
#
#             xmin = -2500
#             xmax = 2500
#             ymin = -20
#             ymax = 100
#             #fig, ax = plt.subplots()
#             ax.set_ylim(ymin, ymax)
#             ax.set_xlim(xmin, xmax)
#             print(type(result.fit_report()))
#
# #             if peak == dict_lines['C_IV_d2']:
# #                 #print(width['C_IV_d2'])
# #                 print(width)
# #                 result = gmodel.fit(b, x = vel_peak, amp= 1e5, cen = 0, wid= width[0])#width['C_IV_d2']) #range add continuum
#
#     i+=1
#
# plt.show()
# fig.suptitle('4C+04.11 26 emission lines continuum subtracted');
# fig.savefig("4C04.11_Spectra_S_N_ratio_noise_new.pdf", format="pdf")
# #fig.savefig("4C04.11_Spectra_with_fit.pdf", format="pdf")
# #fig.savefig('34_Spectra.png', format = 'png')

# %%
#         # get noise option 1 with continuum subtracted spectra
#         condition3_r = (vel_peak >= 4000) & (vel_peak <= 4000 + np.max(FWHM)*2)
#         condition3_l = (vel_peak >= -4000 - np.max(FWHM)*2) & (vel_peak <= -4000 )
#         noise_arr = np.extract(condition3_r, b)
#         noise = np.sum(noise_arr)
#         noise_range = np.extract(condition3_r, vel_peak)
#         #print(noise_range)

# %% [markdown]
# ### Appendix
# * spectra plot with continnum with function
